# %% [markdown]
# <a href="https://colab.research.google.com/github/DereckDanielLopezRodarte/FundamentosProgramacion/blob/main/Unidad1/Programa2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 5
x = "hola mundo"
x = True
print ("el valor de x es", x )
# Out:
# el valor de x es True

# %%
base = int(input("dame la base del triangulo"))
altura = int(input("dame la altura del trinagulo"))
area = (base * altura)/2
__builtins__.print("el area del triangulo es", area)
# Out:
# dame la base del triangulo60
# dame la altura del trinagulo80
# el area del triangulo es 2400.0

# %%
variable1 = 30
variable2 = 50
if variable1 > variable2:
 print(variable1," es mayor que ",variable2)
else:
 __builtins__.print(variable2," es mayor que ",variable1)
# Out:
# 50  es mayor que  30

# %%
edad = int(input ("Dame tu edad "))
if edad <= 10:
  print( "Eres un niño")
elif edad <= 18:
  print( "Eres un adolescente")
elif edad <= 30:
  print( "Eres un adulto joven")
elif edad <= 65:
  print ("Eres un adulto")
else:
  print ("Eres de la tercera edad")
# Out:
# Dame tu edad 80
# Eres de la tercera edad

# %%
edad = int(input ("Dame tu edad "))
if edad > 65:
  print ("Eres de la tercera edad")
elif edad > 30:
  print ("Eres un adulto")
elif edad > 18:
  print( "Eres un adulto joven")
elif edad > 10:
  print( "Eres un adolescente")
else:
  print( "Eres un niño")
# Out:
# Dame tu edad 80
# Eres de la tercera edad

# %%
10 > 5 and 10 > 7 and 10 > 1
# Out:
# False

# %%
10 > 5 and 10 > 7 and 10 > 11
# Out:
# False

# %%
10 > 5 or 10 > 7 or 10 > 11
# Out:
# True

# %%
edad = int(input ("Dame tu edad "))
if edad >= 66:
 print( "Eres un adulto mayor")
elif edad >= 31 and edad <=65 :
 print( "Eres un adulto")
elif edad >= 19 and edad <= 30:
 print( "Eres un adulto joven")
elif edad >= 11 and edad <= 18:
 print( "Eres un adolescente")
else:
 print( "Eres un niño")
# Out:
# Dame tu edad 28
# Eres un adulto joven

# %%
tabla = 7
for i in range(10):
 print (tabla, "*",i,"=",tabla*i)
# Out:
# 7 * 0 = 0
# 7 * 1 = 7
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# 7 * 7 = 49
# 7 * 8 = 56
# 7 * 9 = 63

# %%
tabla = 7
for i in range(10,100,5):
 print (tabla, "*",i,"=",tabla*i)
# Out:
# 7 * 10 = 70
# 7 * 15 = 105
# 7 * 20 = 140
# 7 * 25 = 175
# 7 * 30 = 210
# 7 * 35 = 245
# 7 * 40 = 280
# 7 * 45 = 315
# 7 * 50 = 350
# 7 * 55 = 385
# 7 * 60 = 420
# 7 * 65 = 455
# 7 * 70 = 490
# 7 * 75 = 525
# 7 * 80 = 560
# 7 * 85 = 595
# 7 * 90 = 630
# 7 * 95 = 665
