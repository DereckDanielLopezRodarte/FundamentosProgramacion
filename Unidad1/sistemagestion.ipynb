# %% [markdown]
# <a href="https://colab.research.google.com/github/DereckDanielLopezRodarte/FundamentosProgramacion/blob/main/Unidad1/sistemagestion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Ingenerias computacionales**
# ##**Fundamentos en investigacio**
# ## **UNIDAD 1**
#
# ### Sistema de Gestion dde prestamos y reservaciones de computadoras-Version 1
# Docente: **Jose Gabriel Rodrigues Rivas**
#
# Alumno : **Dereck Daniel Lopez Rodarte**

# %%
# SISTEMA DE PRÉSTAMOS
# Versión 1 - Programación basica y uso de listas
# =！！
# ニニニニニニ
# Lista de alumnos activos en el sistema
alumnos = ["26040200", "26040201", "26040202",
           "26040203",
           "26040204"]
# Cada valor en la lista de computadoras tiene su lista correspondiente con el
# aula donde esta ubicada, el software instalado y el estado de esa computadora
computadoras = ["PC-LC1-01", "PC-LC1-02",
                "PC-LC1-03",
                "PC-LC2-01", "PC-LC2-02",
                "PC-LC2-03",
                "PC-LC3-01", "PC-LC3-02",
                "PC-LC3-03",
                "PC-LC3-04"]
aulas = ["LC1",
         "LC1",
         "LC1",
         "LC2",
         "LC2",
         "LC2",
         "LC3",
         "LC3",
         "LC3",
         "LC3"]
software = ["Python, VS Code", "Python, Java, VS Code", "AutoCAD, MATLAB",
            "Python, VS Code",
            "Python, Java, VS Code", "AutoCAD, MATLAB",
            "Python, VS Code", "Python, Java, VS Code", "AutoCAD, MATLAB", "Python, VS Code"]
estados = ["Disponible", "Prestada", "Reservada",
           "Disponible",
           "Prestada",
           "Reservada",
           "Disponible", "Prestada",
           "Reservada",
           "Mantenimiento"]
# MENÚ PRINCIPAL
# Usamos un ciclo While que se repetira indefinidamente hasta que el usuario
# teclee la opcion 7 (salir) o cualquier numero superior a 7
opcion = 0
while opcion <= 6:
    print("\n==========================")
    print("       SISTEMA DE PRÉSTAMOS")
    print("==========================")
    print("1. Consultar computadoras")
    print("2. Buscar por software")
    print("3. Solicitar préstamo")
    print("4. Devolver computadora")
    print("5. Crear reservación")
    print("6. Agregar computadora")
    print("7. Salir")
    print("==========================")
    opcion = int(input("Seleccione una opción: "))

    # 1. Consultar computadoras
    # si el usuario selecciono la opcion 1 se hace un ciclo (for) que recorre
    # toda la lista de computadoras e imprime los valores de las demás listas
    if opcion == 1:
        print("\n--- COMPUTADORAS ---")
        for i in range(len(computadoras)):
            print(f"Aula: {aulas[i]},ID: {computadoras[i]},Software: {software[i]},Estado: {estados[i]}")

            print("---------------------")

    # 2. Buscar por software
    elif opcion == 2:
        programa = input("\nIngrese el software que desea buscar: ")
        print("\n--- RESULTADOS ---")
        encontrado = False
        for i in range(len(computadoras)):
            # la funcion (lower) convierte a minuscula el texto, de esta forma
            # nos aseguramos que el texto a buscar y la informacion de las listas
            # este en minuscula y no tengamos problema de que no encunentra un programa
            # porque este escrito de forma diferente usando mayusculas y minusculas
            if programa.lower() in software[i].lower():
                print(f"ID: {computadoras[i]}")
                print(f"Aula: {aulas[i]}")
                print(f"Software: {software[i]}")
                print(f"Estado: {estados[i]}")
                encontrado = True
        if encontrado == False:
            print("No se encontraron computadoras con ese software.")
# Out:
# ==========================
#        SISTEMA DE PRÉSTAMOS
# ==========================
# 1. Consultar computadoras
# 2. Buscar por software
# 3. Solicitar préstamo
# 4. Devolver computadora
# 5. Crear reservación
# 6. Agregar computadora
# 7. Salir
# ==========================
#
# --- COMPUTADORAS ---
# Aula: LC1,ID: PC-LC1-01,Software: Python, VS Code,Estado: Disponible
# ---------------------
# Aula: LC1,ID: PC-LC1-02,Software: Python, Java, VS Code,Estado: Prestada
# ---------------------
# Aula: LC1,ID: PC-LC1-03,Software: AutoCAD, MATLAB,Estado: Reservada
# ---------------------
# Aula: LC2,ID: PC-LC2-01,Software: Python, VS Code,Estado: Disponible
# ---------------------
# Aula: LC2,ID: PC-LC2-02,Software: Python, Java, VS Code,Estado: Prestada
# ---------------------
# Aula: LC2,ID: PC-LC2-03,Software: AutoCAD, MATLAB,Estado: Reservada
# ---------------------
# Aula: LC3,ID: PC-LC3-01,Software: Python, VS Code,Estado: Disponible
# ---------------------
# Aula: LC3,ID: PC-LC3-02,Software: Python, Java, VS Code,Estado: Prestada
# ---------------------
# Aula: LC3,ID: PC-LC3-03,Software: AutoCAD, MATLAB,Estado: Reservada
# ---------------------
# Aula: LC3,ID: PC-LC3-04,Software: Python, VS Code,Estado: Mantenimiento
# ---------------------
#
# ==========================
#        SISTEMA DE PRÉSTAMOS
# ==========================
# 1. Consultar computadoras
# 2. Buscar por software
# 3. Solicitar préstamo
# 4. Devolver computadora
# 5. Crear reservación
# 6. Agregar computadora
# 7. Salir
# ==========================

# %%
opcion = 0
while opcion <= 6:
  print ("1. Listar computadora")
  print ("2. Buscar programa/App/Sostware")
  print ("3. Prestar computadora")
  print ("4. Devolver computadora")
  print ("5. Reservar computadora")
  print ("6. Agregar computadora")
  print ("7. Salir")
  opcion = int(input("Seleccione una opción: "))
  if opcion == 1:
    print ("Listado de computadoras")
  elif opcion == 2:
    print ("Buscar por programa")
  elif opcion == 3:
    print ("Prestar computadora")
  elif opcion == 4:
    print ("Devolver computadora")
  elif opcion == 5:
    print ("Reservar computadora")
  elif opcion == 6:
    print ("Agregar computadora")
  elif opcion == 7:
    print ("Salir")
# Out:
# 1. Listar computadora
# 2. Buscar programa/App/Sostware
# 3. Prestar computadora
# 4. Devolver computadora
# 5. Reservar computadora
# 6. Agregar computadora
# 7. Salir
# Seleccione una opción: 5
# Reservar computadora
# 1. Listar computadora
# 2. Buscar programa/App/Sostware
# 3. Prestar computadora
# 4. Devolver computadora
# 5. Reservar computadora
# 6. Agregar computadora
# 7. Salir
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3948/3811322218.py in <cell line: 0>()
#       8   print ("6. Agregar computadora")
#       9   print ("7. Salir")
# ---> 10   opcion = int(input("Seleccione una opción: "))
#      11   if opcion == 1:
#      12     print ("Listado de computadoras")
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
alumnos =["26040220", "26040221", "26040222", "26040223", "26040224"]

#Cada caloer en la lista tiene si liste correspondiente con el alunmo
computadoras =["PC-LC1-01", "PC-LC1-02", "PC-LC1-03",
               "PC-LC2-01", "PC-LC2-02", "PC-LC2-03",
               "PC-LC3-01", "PC-LC3-02", "PC-LC3-03", "PC-LC3-04"]
aulas = ["LC1", "LC1", "LC1",
         "LC2", "LC2", "LC2",
         "LC3", "LC3", "LC3", "LC3"]
software =["Python, VS Code", "Python, Java VS Code", "AutoCAD, MATLAB",
           "Python, VS Code", "Python, Java VS Code", "AutoCAD, MATLAB",
           "Python, VS Code", "Python, Java VS Code", "AutoCAD, MATLAB", "Python, VS Code"]
estados = ["Disponible", "Prestada", "Reservada",
           "Disponible", "Prestada", "Reservada",
           "Disponible", "Prestada", "Reservada", "Mantenimiento"]

#MENÚ PRINCIPAL
#Usamos el "while" para que se repita
#TECLEE LA OPCION 7 QUE ES SALIR O CUALQUIER OTRO MAYOR QUE 7
opcion = 0
while opcion <= 6:
  print("=============================")
  print("   SISTEMAS DE PRESTAMOS")
  print("=============================")
  print("1. Consultar computadoras")
  print("2. Buscar por software")
  print("3. Solicitar préstamo")
  print("4. Devolver computadora")
  print("5. Crear reservavión")
  print("6. Agregar computadora")
  print("7. Salir")
  print("=============================")
  opcion = int(input("Seleccione una opción: "))
#1. Consultar computadoras
#PD: Para que agarre el if de opcion == 1 debe de estar en la misma tabulacion que la de los prints
  if opcion == 1:
    print("-------------------------------------------COMPUTADORAS-----------------------------------------")
    for i in range(len(computadoras)):
      print("          Aula: ", aulas[i], ", ID:", computadoras[i], ", Software:", software[i], ", Estado:", estados[i])
      print("------------------------------------------------------------------------------------------------")
#2 Buscar se software
  elif opcion == 2:
      programa = input("Ingrese el sofware que quieres buscar: ")
      print("---Resultados---")
      encontrado = False
      for i in range(len(computadoras)):
        if programa.lower() in software[i].lower():
          print("Aula: ", aulas[i], "ID: ", computadoras[i], "Software: ", software[i], "Estado: ", estados[i])
          encontrado = True
      if encontrado == False:
        print("No hay computadoras con ese software")
#3 Solictar prestamo
  elif opcion == 3:
    print("---Solicitar prestamo---")
    num_control = input("Ingrese su numero de control: ")
    if num_control in alumnos:
      programa = input("Que programa necesitas: ")
      for i in range(len(computadoras)):
        if programa.lower() in software[i].lower():
          if estados[i] == "Disponible":
            estados[i] = "Prestada"
            print("Se te asigno la computadora", computadoras[1], ", Que se encuentra en la Aula", aulas[i])
          else:
            print("si esta el sofware pero esta", estados[1])
            break
    else:
      print("El alumno no existe")



    #6 Agregar una computadora
  elif opcion == 6:
    print("---Agregar una computadora---")
    id_computadora = input("Ingrese el ID de la computadora: ")
    aula = input("Aula")
    programa = input("Ingrese el sofware que quieres agregar: ")
    computadoras.append(id_computadora)
    aulas.append(aula)
    software.append(programa)
    estados.append("Disponible")
    print("La computadora ha sido agregada correctamente")

  #7 Despedida
  elif opcion >= 7:
    print("Gracias por usar el sistema de prestamos")
    print("Vuelva pronto :)")
# Out:
# =============================
#    SISTEMAS DE PRESTAMOS
# =============================
# 1. Consultar computadoras
# 2. Buscar por software
# 3. Solicitar préstamo
# 4. Devolver computadora
# 5. Crear reservavión
# 6. Agregar computadora
# 7. Salir
# =============================
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.13/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#     ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_2080/1713253898.py", line 33, in <cell line: 0>
#     opcion = int(input("Seleccione una opción: "))
#                  ~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py", line 1177, in raw_input
#     return self._input_request(
#            ~~~~~~~~~~~~~~~~~~~^
#         str(prompt),
#         ^^^^^^^^^^^^
#     ...<2 lines>...
#         password=False,
#         ^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py", line 1219, in _input_request
#     raise KeyboardInterrupt("Interrupted by user") from None
# KeyboardInterrupt: Interrupted by user
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.13/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.13/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.13/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.13/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#                                           ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/inspect.py", line 1756, in getinnerframes
#     traceback_info = getframeinfo(tb, context)
#   File "/usr/lib/python3.13/inspect.py", line 1705, in getframeinfo
#     lines, lnum = findsource(frame)
#                   ~~~~~~~~~~^^^^^^^
#   File "/usr/local/lib/python3.13/dist-packages/IPython/core/ultratb.py", line 182, in findsource
#     lines = linecache.getlines(file, globals_dict)
#   File "/usr/lib/python3.13/linecache.py", line 41, in getlines
#     return updatecache(filename, module_globals)
#   File "/usr/lib/python3.13/linecache.py", line 167, in updatecache
#     with tokenize.open(fullname) as fp:
#          ~~~~~~~~~~~~~^^^^^^^^^^
#   File "/usr/lib/python3.13/tokenize.py", line 457, in open
#     encoding, lines = detect_encoding(buffer.readline)
#                       ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/tokenize.py", line 426, in detect_encoding
#     first = read_or_stop()
#   File "/usr/lib/python3.13/tokenize.py", line 384, in read_or_stop
#     return readline()
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_2080/1713253898.py in <cell line: 0>()
#      32   print("=============================")
# ---> 33   opcion = int(input("Seleccione una opción: "))
#      34 #1. Consultar computadoras
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#
# KeyboardInterrupt: Interrupted by user
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.13/dist-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2098                         # in the engines. This should return a list of strings.
# -> 2099                         stb = value._render_traceback_()
#    2100                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /usr/local/lib/python3.13/dist-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2099                         stb = value._render_traceback_()
#    2100                     except Exception:
# -> 2101                         stb = self.InteractiveTB.structured_traceback(etype,
#    2102                                             value, tb, tb_offset=tb_offset)
#    2103
#
# /usr/local/lib/python3.13/dist-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# /usr/local/lib/python3.13/dist-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# /usr/local/lib/python3.13/dist-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1122         """Return a nice text document describing the traceback."""
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#    1126
#
# /usr/local/lib/python3.13/dist-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# /usr/local/lib/python3.13/dist-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()
